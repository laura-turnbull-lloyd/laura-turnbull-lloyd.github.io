# %% [markdown]
# <a href="https://colab.research.google.com/github/laura-turnbull-lloyd/laura-turnbull-lloyd.github.io/blob/master/Laura_test_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction**
#
# This is a test to see if I can run some of my teaching in R in a Jupyter notebook.
#
# First, we need to install packages.

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Once we've installed the packges, we then need to call them using the library command.

# %%
library("ggplot2")

# %%
getwd()
# Out:
# [1] "/content"

# %% [markdown]
# # Upload data
#
# Go to the folder icon on the left and click the upload bitton. Navigate to file. You will need to do this each time.

# %%
data <- read.csv("modis_fire_area.csv")
data
summary(data)
# Out:
#    X           names.x.    area_km2 date       year month est..dates.from.VIRS
# 1                            0.0000 01/01/2000 2000  1
# 2  X2001_03_01 X2001_03_01   3.6387 01/03/2001 2001  3    14/03/2001
# 3  X2002_03_01 X2002_03_01  13.5111 01/03/2002 2002  3    25/02/2002
# 4  X2003_03_01 X2003_03_01  12.1289 01/03/2003 2003  3    26/02/2003
# 5  X2005_03_01 X2005_03_01   5.3638 01/03/2005 2005  3    07/03/2005
# 6  X2005_04_01 X2005_04_01   0.6441 01/04/2005 2005  4
# 7  X2006_03_01 X2006_03_01   3.4486 01/03/2006 2006  3    05/03/2006
# 8  X2007_03_01 X2007_03_01  18.8758 01/03/2007 2007  3    04/03/2007
# 9  X2008_02_01 X2008_02_01  18.3795 01/02/2008 2008  2    26/02/2008
# 10 X2008_08_01 X2008_08_01   4.0666 01/08/2008 2008  8
# 11 X2008_09_01 X2008_09_01   1.2834 01/09/2008 2008  9
# 12 X2009_03_01 X2009_03_01   5.3621 01/03/2009 2009  3    03/03/2009
# 13 X2009_04_01 X2009_04_01  13.9174 01/04/2009 2009  4    02/04/2009
# ...
